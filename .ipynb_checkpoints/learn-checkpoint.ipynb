# %%
import pandas as pd
surveys_df = pd.read_csv("vgsales.csv")

# %%
surveys_df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data=surveys_df[(surveys_df.Year >= 2010) & (surveys_df.Year <= 2015)]

# %%
data.head(60)
# Out:
#      Rank                                       Name Platform    Year  \
# 15     16                         Kinect Adventures!     X360  2010.0
# 16     17                         Grand Theft Auto V      PS3  2013.0
# 23     24                         Grand Theft Auto V     X360  2013.0
# 26     27                Pokemon Black/Pokemon White       DS  2010.0
# 29     30             Call of Duty: Modern Warfare 3     X360  2011.0
# 31     32                    Call of Duty: Black Ops     X360  2010.0
# 32     33                        Pokemon X/Pokemon Y      3DS  2013.0
# 33     34                  Call of Duty: Black Ops 3      PS4  2015.0
# 34     35                 Call of Duty: Black Ops II      PS3  2012.0
# 35     36                 Call of Duty: Black Ops II     X360  2012.0
# 37     38             Call of Duty: Modern Warfare 3      PS3  2011.0
# 40     41                    Call of Duty: Black Ops      PS3  2010.0
# ...

# %%
d1=data[(data.Year == 2012) & (data.Publisher == 'Ubisoft')]

# %%
d1.head(60)
# Out:
#         Rank                                      Name Platform    Year  \
# 111      112                              Just Dance 4      Wii  2012.0
# 128      129                      Assassin's Creed III      PS3  2012.0
# 172      173                      Assassin's Creed III     X360  2012.0
# 382      383                                 Far Cry 3      PS3  2012.0
# 459      460                                 Far Cry 3     X360  2012.0
# 1286    1288          Assassin's Creed III: Liberation      PSV  2012.0
# 1299    1301  Tom Clancy's Ghost Recon: Future Soldier     X360  2012.0
# 1703    1705                              Just Dance 4     X360  2012.0
# 2029    2031                                    ZombiU     WiiU  2012.0
# 2106    2108                                 Far Cry 3       PC  2012.0
# 2164    2166  Tom Clancy's Ghost Recon: Future Soldier      PS3  2012.0
# 2202    2204                      Assassin's Creed III       PC  2012.0
# ...
